# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Instalación y Preparación del Entorno\n",
    "\n",
    "Este notebook te guiará para preparar todo lo necesario para ejecutar el proyecto **VM vs Docker Benchmark - PacMan Game**."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Requisitos previos\n",
    "- Tener instalado Java (JDK 11 o superior)\n",
    "- Tener instalado Docker\n",
    "- Tener instalado Python 3 y Jupyter Notebook\n",
    "- Tener acceso a la terminal o consola de comandos"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Verificar versión de Java\n",
    "!java -version"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Verificar versión de Docker\n",
    "!docker --version"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Verificar versión de Python\n",
    "!python3 --version"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Crear la estructura del proyecto\n",
    "Ejecuta el siguiente comando para crear las carpetas y archivos necesarios con el script `setup_project.sh`."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "!chmod +x ../setup_project.sh && ../setup_project.sh"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Próximos pasos\n",
    "- Ejecutar `scripts/vm_setup.sh` para compilar y correr el juego en la máquina local.\n",
    "- Ejecutar `scripts/docker_setup.sh` para construir y correr el contenedor Docker.\n",
    "- Abrir y correr `notebooks/vm_vs_docker_comparison.ipynb` para comparar tiempos de ejecución."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
